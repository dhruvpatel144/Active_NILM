# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = str(1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
from dataloader import *
from model import *
from utilities import *
from retrain_fun import *
import random

random.seed(0)
np.random.seed(0)
jax.random.PRNGKey(0)
os.environ["XLA_FLAGS"] = "--xla_gpu_deterministic_reductions --xla_gpu_autotune_level=2"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
# Out:
# 2023-05-07 14:13:12.998911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_aggregated, houses = data_preprocess(only_positive=True)

# %% [markdown]
# Train: [2361, 7719, 9019, 2335, 7951]
# Test:  [4373, 7901, 3456, 3538, 2818]

# %%
train_list = [[2361, 7719, 9019, 2335, 7951]]
test_list = [[4373, 7901, 3456, 3538, 2818]]
pool_list = []
for i in range(len(train_list)):
    pool = [j for j in houses if j not in train_list[i] + test_list[i]]
    pool_list.append(pool)

# %%
appliance = "air"

# %%
pool_list
# Out:
# [[5746, 8565, 9278, 8156, 8386, 9160, 661, 1642, 7536, 7800]]

# %%
total_rmse = []
houseids = []
for i in range(len(train_list)):
    # print(len(train_list))
    print("Train Set No:", i + 1)
    train_houses = train_list[i]
    test_houses = test_list[i]
    pool_houses = pool_list[i]
    train = data_aggregated[data_aggregated["dataid"].isin(train_houses)]
    test = data_aggregated[data_aggregated["dataid"].isin(test_houses)]

    rmse_iter = []
    houses = []
    start = [
        "2018-03-01 00:00:00-06",
        "2018-03-11 00:00:00-06",
        "2018-03-16 00:00:00-06",
        "2018-03-21 00:00:00-06",
        "2018-03-26 00:00:00-06",
        "2018-04-01 00:00:00-06",
        "2018-04-06 00:00:00-06",
        "2018-04-11 00:00:00-06",
        "2018-04-16 00:00:00-06",
        "2018-04-21 00:00:00-06",
    ]
    end = [
        "2018-03-10 23:59:00-06",
        "2018-03-15 23:59:00-06",
        "2018-03-20 23:59:00-06",
        "2018-03-25 23:59:00-06",
        "2018-03-31 23:59:00-06",
        "2018-04-05 23:59:00-06",
        "2018-04-10 23:59:00-06",
        "2018-04-15 23:59:00-06",
        "2018-04-20 23:59:00-06",
        "2018-04-25 23:59:00-06",
    ]
    dates = [
        "2018-03-01 00:00:00-06",
        "2018-03-06 00:00:00-06",
        "2018-03-11 00:00:00-06",
        "2018-03-16 00:00:00-06",
        "2018-03-21 00:00:00-06",
        "2018-03-27 00:00:00-06",
        "2018-04-01 00:00:00-06",
        "2018-04-06 00:00:00-06",
        "2018-04-11 00:00:00-06",
        "2018-04-16 00:00:00-06",
    ]
    for j in range(len(start)):
        # print(len(start))
        print("Iteration No: ", j)
        if j == 0:
            house, houseid, rmsee, train, test = retrain(
                0, start[j], end[j], pool_houses, train, test, dates[j], appliance, data_aggregated
            )
            rmse_iter.append(rmsee.item())
            houses.append(house)
            pool_houses = np.delete(pool_houses, houseid)
        elif j == 10:
            house, houseid, rmsee, train, test = retrain(
                house, start[j], end[j], pool_houses, train, test, dates[j], appliance, data_aggregated
            )
            rmse_iter.append(rmsee.item())
        else:
            house, houseid, rmsee, train, test = retrain(
                house, start[j], end[j], pool_houses, train, test, dates[j], appliance, data_aggregated
            )
            rmse_iter.append(rmsee.item())
            houses.append(house)
            pool_houses = np.delete(pool_houses, houseid)
    total_rmse.append(rmse_iter)
    houseids.append(houses)
# Out:
# Train Set No: 1
# Iteration No:  0
# (10, 58739, 1)
# RMSE : 842.1524 MAE  : 329.9018 NLL : 1385.3068
# Iteration No:  1
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156]
# RMSE : 841.9338 MAE  : 331.9903 NLL : 3004.1052
# Iteration No:  2
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536]
# 2023-05-07 14:18:38.544987: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[117888,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[117888,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 800.4500 MAE  : 312.6795 NLL : 4.9114
# Iteration No:  3
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746]
# 2023-05-07 14:20:38.644845: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[161792,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[161792,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:20:39.715653: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[161792,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[161792,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:20:40.869426: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[161792,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[161792,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 718.4362 MAE  : 281.6801 NLL : 4.6703
# Iteration No:  4
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160]
# 2023-05-07 14:22:27.460264: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[217605,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[217605,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:22:28.614544: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[217605,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[217605,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:22:30.053469: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[217605,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[217605,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:22:31.479748: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[217605,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[217605,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 570.3935 MAE  : 225.5371 NLL : 7.2779
# Iteration No:  5
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160 9278]
# 2023-05-07 14:24:14.491555: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[270269,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[270269,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:24:15.882104: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[270269,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[270269,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:24:17.453365: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[270269,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[270269,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:24:19.183908: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[270269,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[270269,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 205.1767 MAE  : 71.1951 NLL : 4.3655
# Iteration No:  6
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160 9278 1642]
# 2023-05-07 14:25:58.548939: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[330196,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[330196,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:26:00.177754: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[330196,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[330196,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:26:02.087003: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[330196,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[330196,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:26:04.209800: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[330196,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[330196,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 201.9680 MAE  : 67.2197 NLL : 5.0517
# Iteration No:  7
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160 9278 1642 7800]
# 2023-05-07 14:27:34.863543: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[395691,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[395691,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:27:36.789618: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[395691,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[395691,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:27:38.983584: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[395691,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[395691,40,99]{2,1,0}, f32[50,40,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:27:41.404668: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[395691,50,99]{2,1,0}, u8[0]{0}) custom-call(f32[395691,50,99]{2,1,0}, f32[50,50,5]{2,1,0}), window={size=5 pad=2_2}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 163.6275 MAE  : 54.3076 NLL : 4.2869
# Iteration No:  8
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160 9278 1642 7800 8565]
# 2023-05-07 14:29:06.405563: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[468634,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[468634,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 163.6820 MAE  : 51.3784 NLL : 4.4127
# Iteration No:  9
# /home/dhruv.patel/final_active/pos/retrain_fun.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train.append(new_df)
# Train houses are
# [7719 9019 2335 2361 7951 8156 7536 5746 9160 9278 1642 7800 8565  661]
# 2023-05-07 14:30:36.328051: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[547597,30,99]{2,1,0}, u8[0]{0}) custom-call(f32[547597,30,106]{2,1,0}, f32[30,30,8]{2,1,0}), window={size=8}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# 2023-05-07 14:30:39.047878: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gpu_conv_algorithm_picker.cc:825] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.  Conv: (f32[547597,40,99]{2,1,0}, u8[0]{0}) custom-call(f32[547597,30,104]{2,1,0}, f32[40,30,6]{2,1,0}), window={size=6}, dim_labels=bf0_oi0->bf0, custom_call_target="__cudnn$convForward", backend_config="{\"conv_result_scale\":1,\"activation_mode\":\"0\",\"side_input_scale\":0}"
# RMSE : 140.8409 MAE  : 45.3425 NLL : 4.0124

# %%
houseids
# Out:
# [[8156, 7536, 5746, 9160, 9278, 1642, 7800, 8565, 661, 8386]]

# %%
total_rmse
# Out:
# [[842.1524047851562,
#   841.933837890625,
#   800.449951171875,
#   718.4362182617188,
#   570.3934936523438,
#   205.17669677734375,
#   201.96795654296875,
#   163.6275177001953,
#   163.68202209472656,
#   140.8408660888672]]

# %%
d = pd.DataFrame(total_rmse)
house_df = pd.DataFrame(houseids)
if not os.path.exists(f"{appliance}"):
    os.mkdir(f"{appliance}")

# Save the DataFrame to a CSV file
d.to_csv(os.path.join(f"{appliance}", "errors.csv"), index=False)
house_df.to_csv(os.path.join(f"{appliance}", "houseids.csv"), index=False)

# %%
plt.plot(total_rmse[0])

plt.xlabel("#Iterations")
plt.ylabel("RMSE")
plt.title("air")
# Out:
# Text(0.5, 1.0, 'air')
